# %%
from pymna import Circuit
from pymna.units import kOhm,uF, V, Hz, um, kHz
from pymna.simulator import Simulator
import matplotlib.pyplot as plt
import os

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %matplotlib ipympl
# %autoreload 2
basepath = os.getcwd()
print(basepath)
# Out:
# /Users/jodafons/Desktop/pymna/examples

# %%
circuit = Circuit()
circuit.SinusoidalVoltageSource('in', circuit.gnd, 
                                amplitude=1, 
                                frequency=10, 
                                number_of_cycles=10, 
                                dc=0,
                                angle=90,
                                name='Vsin')


circuit.Diode('in','out',name='D1')
circuit.R('out',circuit.gnd,1*kOhm, name='RL')
circuit.C('out',circuit.gnd, 1e-3)

simulator = Simulator()
r = simulator.transient( circuit , 0.5, 0.001)
# Out:
# Transient simulation started with end_time=0.5, step_time=0.001
# max_number_of_internal_step=1, max_tolerance=0.0001
# Max number of nodes: 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[267], line 16
#      13 circuit.C('out',circuit.gnd, 1e-3)
#      15 simulator = Simulator()
# ---> 16 r = simulator.transient( circuit , 0.5, 0.001)
#
# File ~/Desktop/pymna/pymna/simulator/mna.py:241, in Simulator.transient(self, circuit, end_time, step_time, max_tolerance, max_number_of_internal_step, max_number_of_guesses, max_number_of_newton_raphson, step_factor, verbose, method)
#     239 result = {"t":times}
#     240 for col_idx, col_name in enumerate(col_names):
# --> 241     result[ col_name ] = e[ :, col_idx+1 ]
#     243 return result
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
r.keys()
# Out:
# dict_keys(['t', '1', '2', 'J3Vsin'])

# %%
plt.style.use('dark_background')

fig, ax = plt.subplots()
plt.plot( r['t'], r['1'], color='blue' )
plt.plot( r['t'], r['2'], color='red' )

ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# signal input
fs = 1000*Hz
Ts = 1/fs
ns = 3
end_time = (Ts)*ns

# clock signal
#fclk = 2*fs
#Tclk = 1/fclk 
#nclk = end_time / (Tclk)



circuit = Circuit()

circuit.VoltageSource('drain',circuit.gnd, 5)
circuit.mosfet_channel_n('drain', 'gate', 'source' , W=5*um , L=5*um )
circuit.PulseVoltageSource( 'gate', circuit.gnd,
                                    amplitude_1 = 0,
                                    amplitude_2 = 7,
                                    T = Ts,
                                    number_of_cycles = ns,
                                    #rise_time=0.001,
                                    #fall_time=0.001,
                                    time_on = Ts*0.2)
circuit.R('source', circuit.gnd, 1000000)
#circuit.C('source', circuit.gnd, 1e-8)
print(circuit.nodes)
simulator = Simulator()
r = simulator.transient( circuit , end_time, 0.00001, verbose=False)
plt.style.use('dark_background')
fig, ax = plt.subplots()
plt.plot( r['t'], r['drain'] , color='green' )
plt.plot( r['t'], r['gate']  , color='blue' )
plt.plot( r['t'], r['source'], color='red' )
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("")
plt.show()
# Out:
# {0: 0, 'drain': 1, 'gate': 2, 'source': 3}
# Transient simulation started with end_time=0.003, step_time=1e-05
# max_number_of_internal_step=1, max_tolerance=0.0001
# Max number of nodes: 3
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()
plt.plot( r['t'], r['drain'] , color='green' )
plt.plot( r['t'], r['gate']  , color='blue' )
plt.plot( r['t'], r['source'], color='red' )
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# !pip install git+https://github.com/FabriceSalvaire/PySpice
# Out:
# Collecting git+https://github.com/FabriceSalvaire/PySpice
#   Cloning https://github.com/FabriceSalvaire/PySpice to /private/var/folders/h9/q5xyn9l91ws7z7n6pn85fts40000gn/T/pip-req-build-pdbgcbju
#   Running command git clone --filter=blob:none --quiet https://github.com/FabriceSalvaire/PySpice /private/var/folders/h9/q5xyn9l91ws7z7n6pn85fts40000gn/T/pip-req-build-pdbgcbju
#   Resolved https://github.com/FabriceSalvaire/PySpice to commit fe08718d5a1a9af94576b5aef1fa81910f09b037
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.3 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from PySpice==1.5) (6.0.2)
# Requirement already satisfied: cffi>=1.14 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from PySpice==1.5) (1.17.1)
# Requirement already satisfied: matplotlib>=3.2 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from PySpice==1.5) (3.10.3)
# Requirement already satisfied: numpy>=1.18 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from PySpice==1.5) (2.2.6)
# Collecting ply>=3.11 (from PySpice==1.5)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting scipy>=1.4 (from PySpice==1.5)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: requests>=2.23 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from PySpice==1.5) (2.32.4)
# Requirement already satisfied: pycparser in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from cffi>=1.14->PySpice==1.5) (2.22)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from matplotlib>=3.2->PySpice==1.5) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from requests>=2.23->PySpice==1.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from requests>=2.23->PySpice==1.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from requests>=2.23->PySpice==1.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from requests>=2.23->PySpice==1.5) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /Users/jodafons/Desktop/pymna/pymna-env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2->PySpice==1.5) (1.17.0)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Building wheels for collected packages: PySpice
#   Building wheel for PySpice (setup.py) ... done
#   Created wheel for PySpice: filename=pyspice-1.5-py2.py3-none-any.whl size=158459 sha256=d564c10cdefb80ea27a7b6375800230da7031d635ba06d1c1c4bd0636a30e25d
#   Stored in directory: /private/var/folders/h9/q5xyn9l91ws7z7n6pn85fts40000gn/T/pip-ephem-wheel-cache-prte9jya/wheels/42/fa/bc/d2dca28291c2faf35a88c2d118f956f3178f7a8589987ecc52
# Successfully built PySpice
# Installing collected packages: ply, scipy, PySpice
# Successfully installed PySpice-1.5 ply-3.11 scipy-1.15.3
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# signal input
Hz=1
fs = 1000*Hz
Ts = 1/fs
ns = 3
end_time = (Ts)*ns

# clock signal
fclk = 5*fs
Tclk = 1/fclk 
nclk = end_time / (Tclk)

circuit = Circuit()
circuit.SinusoidalVoltageSource('in', circuit.gnd, 
                                amplitude=1, 
                                frequency=fs, 
                                number_of_cycles=ns, 
                                dc=1,
                                name='Vsin')
circuit.OpAmp( 'in', 'out1', 'out1' )
circuit.mosfet_channel_n('out1', 'base', 'in2' , W=5*um , L=5*um )
circuit.PulseVoltageSource( 'base', circuit.gnd,
                                    amplitude_1 = 0,
                                    amplitude_2 = 6,
                                    T = Tclk,
                                    number_of_cycles = nclk,
                                    time_on = 0.1*Tclk)
circuit.C('in2', 'aux', 1e-9 )
circuit.R('in2',circuit.gnd, 10000000)
circuit.R('aux',circuit.gnd,5)
circuit.OpAmp( 'in2', 'out', 'out' )
circuit.R('out', circuit.gnd, 1000)
print(circuit.nodes)
simulator = Simulator()
r = simulator.transient( circuit , end_time, 0.0000001, verbose=False)
plt.style.use('dark_background')
fig, ax = plt.subplots()
plt.plot( r['t'], r['in'] , color='green' )
plt.plot( r['t'], r['base']/3  , color='blue' )
plt.plot( r['t'], r['in2'], color='red' )
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      10 Tclk = 1/fclk
#      11 nclk = end_time / (Tclk)
# ---> 13 circuit = Circuit()
#      14 circuit.SinusoidalVoltageSource('in', circuit.gnd,
#      15                                 amplitude=1,
#      16                                 frequency=fs,
#      17                                 number_of_cycles=ns,
#      18                                 dc=1,
#      19                                 name='Vsin')
#      20 circuit.OpAmp( 'in', 'out1', 'out1' )
#
# NameError: name 'Circuit' is not defined
