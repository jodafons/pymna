# %%
from pymna import Circuit
from pymna.units import kOhm,uF, V, Hz
from pymna.simulator import Simulator
import matplotlib.pyplot as plt
import os

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %matplotlib ipympl
# %autoreload 2
basepath = os.getcwd()
print(basepath)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/jodafons/Desktop/pymna/examples

# %%
circuit = Circuit()
circuit.SinusoidalVoltageSource('in', circuit.gnd, 
                                amplitude=5, 
                                frequency=60, 
                                number_of_cycles=10, 
                                dc=0,
                                name='V1')


circuit.Diode('in','out',name='D1')
circuit.R('out',circuit.gnd,1*kOhm, name='R2')

simulator = Simulator()
r = simulator.transient( circuit , 0.05, 0.0001)
# Out:
# Transient simulation started with end_time=0.05, step_time=0.0001
# max_number_of_internal_step=1, max_tolerance=1
# Max number of nodes: 3
# 101 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 17
#      15 circuit.R('out',circuit.gnd,10*kOhm, name='R2')
#      16 simulator = Simulator()
# ---> 17 r = simulator.transient( circuit , 0.05, 0.0001)
#
# File ~/Desktop/pymna/pymna/simulator/mna.py:199, in Simulator.transient(self, circuit, end_time, step_time, max_tolerance, max_number_of_internal_step, max_number_of_guesses, max_number_of_newton_raphson, step_factor, method)
#     197 if number_of_guesses > max_number_of_guesses:
#     198     print(number_of_guesses, max_number_of_guesses)
# --> 199     raise ImpossibleSolution("Its not possible to found a solution to this problem.")
#     200 x_newton_raphson    = np.random.rand(max_nodes)%100 + 1
#     201 number_of_guesses+=1
#
# TypeError: ImpossibleSolution.__init__() missing 1 required positional argument: 'errors'

# %%
r.keys()
# Out:
# dict_keys(['t', '1', '2', 'J3V1'])

# %%
plt.style.use('dark_background')

fig, ax = plt.subplots()
plt.plot( r['t'], r['1'], color='blue' )
plt.plot( r['t'], r['2'], color='red' )

ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
